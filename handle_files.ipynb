# %%
import os

listOfFiles = []

for (dirpath, dirname, filenames) in os.walk("D:/Python/UNMSM/ResSimulacroPre"):
    listOfFiles += [os.path.join(dirpath, file) for file in filenames]

len(listOfFiles)
#for path in listOfFiles:
#    print(path)
# Out:
# 470
